# %% [markdown]
# # Modifications of triplet loss for deep metric learning tasks
#
# This notebook contains code for experiments with CUB-200-2011 dataset.
#
# Requirements: pandas, numpy, torch, wandb, timm, open-metric-learning

# %%
# !pip uninstall -y numpy torch torchvision torchaudio
# !pip install git+https://github.com/OML-Team/open-metric-learning.git
# !pip uninstall -y nvidia_cublas_cu11
# !pip install wandb

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !pip install git+https://github.com/OML-Team/open-metric-learning.git
# !pip install wandb
# !wandb login "2a3ffdce0110826a26805443c7575053621bc696"

# !wget "https://data.caltech.edu/records/65de6-vp158/files/CUB_200_2011.tgz"
# !tar -zxvf CUB_200_2011.tgz

# !wget "https://raw.githubusercontent.com/OML-Team/open-metric-learning/main/pipelines/datasets_converters/convert_cub.py"
# !python convert_cub.py --dataset_root=/kaggle/working/CUB_200_2011 --no_bboxes

# %%
import datetime as dt
from pathlib import Path

import numpy as np
import pandas as pd
import timm
import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import DataLoader
from tqdm import tqdm

from oml.datasets.base import DatasetWithLabels
from oml.inference.flat import inference_on_images
from oml.losses.triplet import TripletLossWithMiner
from oml.miners.cross_batch import TripletMinerWithMemory
from oml.miners.inbatch_hard_cluster import HardClusterMiner
from oml.miners.inbatch_hard_tri import HardTripletsMiner
from oml.miners.inbatch_nhard_tri import NHardTripletsMiner
from oml.miners.inbatch_all_tri import AllTripletsMiner
from oml.models.vit.vit import ViTExtractor
from oml.samplers.balance import BalanceSampler
from oml.transforms.images.albumentations import (
    get_augs_albu,
    get_normalisation_resize_albu
)
from oml.transforms.images.torchvision import (
    get_augs_hypvit,
    get_normalisation_resize_hypvit
)

import wandb
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
from oml.functional.metrics import (
    calc_gt_mask,
    calc_mask_to_ignore,
    calc_retrieval_metrics,
)


def compute_metrics(dist_mat, labels, is_query, is_gallery, **metrics):
    mask_gt = calc_gt_mask(labels=labels, is_query=is_query, is_gallery=is_gallery)
    mask_to_ignore = calc_mask_to_ignore(is_query=is_query, is_gallery=is_gallery)
    return calc_retrieval_metrics(dist_mat, mask_gt, mask_to_ignore, **metrics)


def transform_metrics_for_wandb_logging(metrics_value):
    res = {}
    for metric_name in metrics_value:
        for k in metrics_value[metric_name]:
            res[metric_name + '/' + str(k)] = metrics_value[metric_name][k].item()
    return res


def save_model(path, num_epochs, model, optimizer, scheduler=None):
    '''Save on GPU'''
    data = {
        'num_epochs': num_epochs,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict() if scheduler is not None else None
    }
    torch.save(data, path)


def load_model(path, device, model, optimizer=None, scheduler=None):
    '''Load on GPU'''
    data = torch.load(path)
    model.load_state_dict(data['model_state_dict'])
    model.to(device)
    if optimizer is not None:
        optimizer.load_state_dict(data['optimizer_state_dict'])
    if scheduler is not None:
        scheduler.load_state_dict(data['scheduler_state_dict'])
    return data['num_epochs']


@torch.no_grad()
def inference(model, valid_loader, device):
    embeds, labels = [], []
    for batch in valid_loader:
        # embeds += [F.normalize(model.body(batch['input_tensors'].to(device)), p=2, dim=1)]
        embeds += [model(batch['input_tensors'].to(device))]
        labels += [batch['labels']]
    return torch.cat(embeds, dim=0).cpu(), torch.cat(labels, dim=0).cpu()


@torch.no_grad()
def track_additional_valid_metrics(embeds, labels, dist_mat):
    additionel_metrics = {}
    
    class_centers, class_sizes = [], []
    for label, count in zip(*torch.unique(labels, return_counts=True)):
        class_embeds = embeds[labels == label]
        class_center = torch.mean(class_embeds, dim=0)
        class_centers += [class_center]
        class_variance = torch.sum((class_embeds - class_center.unsqueeze(0)) ** 2) / count
        class_sizes += [torch.sqrt(class_variance)]
    
    class_sizes = torch.tensor(class_sizes)
    class_centers = torch.stack(class_centers, dim=0)
    class_centers_dist_mat = torch.cdist(class_centers, class_centers, p=2)
    n_classes = class_centers.shape[0]
    
    additionel_metrics['additional/class_sizes/min'] = torch.min(class_sizes)
    additionel_metrics['additional/class_sizes/max'] = torch.max(class_sizes)
    additionel_metrics['additional/class_sizes/mean'] = torch.mean(class_sizes)
    
    additionel_metrics['additional/inter_class_dist/min'] = \
        torch.min(class_centers_dist_mat[class_centers_dist_mat > 0])
    additionel_metrics['additional/inter_class_dist/max'] = torch.max(class_centers_dist_mat)
    additionel_metrics['additional/inter_class_dist/mean'] = \
        torch.sum(class_centers_dist_mat) / float(n_classes) / (n_classes - 1)
    
    return additionel_metrics


@torch.no_grad()
def validation(model, valid_loader, metrics, device):
    model.eval()
    embeds, labels = inference(model, valid_loader, device)
    print(f'Inference finished: {dt.datetime.now()}')

    dist_mat = torch.cdist(embeds, embeds, p=2)
    mask = torch.ones(len(embeds))
    metrics_value = compute_metrics(dist_mat, labels, mask, mask, **metrics)
    wandb_metrics_value = transform_metrics_for_wandb_logging(metrics_value)
    wandb_metrics_value.update(track_additional_valid_metrics(embeds, labels, dist_mat))
    print(wandb_metrics_value, end='\n\n')
    
    return wandb_metrics_value


@torch.no_grad()
def add_train_metrics(wandb_metrics_value, model, train_loader, metrics, device):
    train_metrics_value = validation(model, train_loader, metrics, device)
    for metric, value in train_metrics_value.items():
        wandb_metrics_value['train/' + metric] = value


def curve_relu(x, gamma):
    gamma = float(gamma)
    assert gamma >= 1.0
    
    res = torch.clone(x)
    mask = (res < 0)
    res[mask] = 0.0
    res[torch.logical_not(mask)] **= gamma
    return res


def relu_threshold(x, t):
    t = float(t)
    assert t > 0
    
    res = torch.clone(x)
    res[res < 0] = 0.0
    res[res > t] = t
    return res

# %%
def freeze(model):
    def fr(m):
        for param in m.parameters():
            param.requires_grad = False
    fr(model.patch_embed)
    fr(model.pos_drop)


def rm_head(m):
    names = set(x[0] for x in m.named_children())
    target = {"head", "fc", "head_dist"}
    for x in names & target:
        m.add_module(x, nn.Identity())


class NormLayer(nn.Module):
    def forward(self, x):
        return F.normalize(x, p=2, dim=1)


class Extractor(nn.Module):
    def __init__(self):
        super().__init__()
        self.body = timm.create_model('vit_small_patch16_224', pretrained=True)
        # self.body = torch.hub.load("facebookresearch/dino:main", 'dino_vits16')
        # self.body = ViTExtractor('vits8_dino', arch='vits8', normalise_features=False)
        freeze(self.body)   # freeze MLPs for patch embeds
        
#         self.head = nn.Sequential(nn.Linear(384, 384), NormLayer())
#         nn.init.constant_(self.head[0].bias.data, 0)
#         nn.init.orthogonal_(self.head[0].weight.data)
        rm_head(self.body)
        # self.head = nn.Identity()
        self.head = NormLayer()
    
    def forward(self, x):
        return self.head(self.body(x))

# %% [markdown]
# # Triplet loss implementation from OML library

# %%
from typing import Optional

from oml.functional.losses import get_reduced
from oml.interfaces.miners import labels2list
from oml.utils.misc_torch import elementwise_dist

from torch import Tensor



class MyTripletLoss(nn.Module):
    """
    Class, which combines classical `TripletMarginLoss` and `SoftTripletLoss`.
    The idea of `SoftTripletLoss` is the following:
    instead of using the classical formula
    ``loss = relu(margin + positive_distance - negative_distance)``
    we use
    ``loss = log1p(exp(positive_distance - negative_distance))``.
    It may help to solve the often problem when `TripletMarginLoss` converges to it's
    margin value (also known as `dimension collapse`).
    """

    criterion_name = "triplet"  # for better logging

    def __init__(self, margin: Optional[float], reduction: str = "mean", need_logs: bool = False):
        """
        Args:
            margin: Margin value, set ``None`` to use `SoftTripletLoss`
            reduction: ``mean``, ``sum`` or ``none``
            need_logs: Set ``True`` if you want to store logs
        """
        assert reduction in ("mean", "sum", "none")
        # assert (margin is None) or (margin > 0)

        super().__init__()

        self.margin = margin
        self.reduction = reduction
        self.need_logs = need_logs
        self.last_logs: Dict[str, float] = {}
        
        self.log_dap, self.log_dan, self.log_dpn = [], [], []

    def forward(self, anchor: Tensor, positive: Tensor, negative: Tensor) -> Tensor:
        """
        Args:
            anchor: Anchor features with the shape of ``(batch_size, feat)``
            positive: Positive features with the shape of ``(batch_size, feat)``
            negative: Negative features with the shape of ``(batch_size, feat)``
        Returns:
            Loss value
        """
        assert anchor.shape == positive.shape == negative.shape

        positive_dist = elementwise_dist(x1=anchor, x2=positive, p=2)
        negative_dist = elementwise_dist(x1=anchor, x2=negative, p=2)
        pos_neg_dist = elementwise_dist(x1=positive, x2=negative, p=2)
        
        self.log_dap.append(positive_dist)
        self.log_dan.append(negative_dist)
        self.log_dpn.append(pos_neg_dist)

        if self.margin is None:
            # here is the soft version of TripletLoss without margin
            loss = torch.log1p(torch.exp(positive_dist - negative_dist))
        else:
            # loss = torch.relu(self.margin + positive_dist - negative_dist)
            loss = curve_relu(self.margin + positive_dist - negative_dist, gamma=2.0)
            # loss = relu_threshold(self.margin + positive_dist - negative_dist, t=self.margin + 0.45)

        if self.need_logs:
            self.last_logs = {
                "active_tri": float((loss.clone().detach() > 0).float().mean()),
                "pos_dist": float(positive_dist.clone().detach().mean().item()),
                "neg_dist": float(negative_dist.clone().detach().mean().item()),
            }

        loss = get_reduced(loss, reduction=self.reduction)

        return loss
    
    def summary(self):
        res = {}
        dap, dan, dpn = map(torch.cat, [self.log_dap, self.log_dan, self.log_dpn])
        diff = dan - dap
        for data, name in zip([dap, dan, dpn, diff], 
                              ['d(a,p)', 'd(a,n)', 'd(p,n)', 'd(a,n)-d(a,p)']):
            res[name + '/min'] = torch.min(data).item()
            res[name + '/mean'] = torch.mean(data).item()
            res[name + '/std'] = torch.std(data).item()
            res[name + '/max'] = torch.max(data).item()
        self.log_dap, self.log_dan, self.log_dpn = [], [], []
        return res


class MyTripletLossWithMiner(nn.Module):
    def __init__(self, triplet_loss, miner):
        super().__init__()
        self.tri_loss = triplet_loss
        self.miner = miner
    
    def forward(self, features, labels):
        labels_list = labels2list(labels)
        anchor, positive, negative = self.miner.sample(features=features, labels=labels_list)
        loss = self.tri_loss(anchor=anchor, positive=positive, negative=negative)
        return loss

# %%
dataset_root = '/kaggle/working/CUB_200_2011'
num_workers = 2
valid_batch_size = 128
n_labels = 24
n_instances = 4

lr = 1e-5
wd = 0.01

df = pd.read_csv(dataset_root + '/df.csv')
# use trainval split as in DML articles
df[['is_query', 'is_gallery']] = np.nan
df.loc[df['label'] <= 100, 'split'] = 'train'
df.loc[df['label'] > 100, 'split'] = 'validation'
df.loc[df['label'] > 100, ['is_query', 'is_gallery']] = True

df_train = df[df['split'] == 'train']
df_valid = df[df['split'] == 'validation']

# train_transforms = get_augs_albu(224)
# valid_transforms = get_normalisation_resize_albu(224)
mean, std = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)
train_transforms = get_augs_hypvit(224, mean=mean, std=std)
valid_transforms = get_normalisation_resize_hypvit(256, mean=mean, std=std)

train_dataset = DatasetWithLabels(df_train, transform=train_transforms, dataset_root=dataset_root)
train_dataset_metrics = DatasetWithLabels(df_train, transform=valid_transforms, dataset_root=dataset_root)
valid_dataset = DatasetWithLabels(df_valid, transform=valid_transforms, dataset_root=dataset_root)

sampler = BalanceSampler(train_dataset.get_labels(), n_labels=n_labels, n_instances=n_instances)
train_loader = DataLoader(train_dataset, batch_sampler=sampler, num_workers=num_workers)
train_loader_metrics = DataLoader(train_dataset_metrics, batch_size=valid_batch_size, num_workers=num_workers)
valid_loader = DataLoader(valid_dataset, batch_size=valid_batch_size, num_workers=num_workers)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = Extractor().to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=wd)
scheduler = None
# criterion = TripletLossWithMiner(margin=0.15, miner=HardTripletsMiner())
criterion = MyTripletLossWithMiner(MyTripletLoss(margin=0.2), 
                                   NHardTripletsMiner(n_positive=(2, 2), n_negative=(1, 1)))

# %% [markdown]
# # Training

# %%
# torch.manual_seed(42)

n_epochs = 10000
valid_period = 5

metrics = {
    'cmc_top_k': [1],  # to calculate cmc@1
    'map_top_k': [5],  # to calculate map@5
    'precision_top_k': [],
    'fmr_vals': []
}

wandb_init_data = {
    'project': 'TP3',
    'name': 'run',
    'save_code': True,
    'config': {
        'model': 'ViT',
        'optimizer': optimizer,
        'scheduler': scheduler,
        'sampler': {
            'name': 'balanced',
            'n_labels': n_labels,
            'n_instances': n_instances
        },
        
        'valid_period': valid_period,

        'dataset': 'CUB_200_2011',
        'num_epochs': n_epochs,
        'dataloader_num_workers': num_workers,
        'script': _ih[-1]
    }
}

with wandb.init(**wandb_init_data) as run:
    print('Evaluating pre-trained model before training')
    wandb_metrics_value = validation(model, valid_loader, metrics, device)
    add_train_metrics(wandb_metrics_value, model, train_loader_metrics, metrics, device)
    wandb.log(wandb_metrics_value)
    best_cmc1 = wandb_metrics_value['cmc/1']
    
    for epoch in range(n_epochs):
        model.train()
        for batch in train_loader:
            optimizer.zero_grad()
            embeddings = model(batch['input_tensors'].to(device))
            loss = criterion(embeddings, batch['labels'].to(device))
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 3)
            optimizer.step()

        if (epoch + 1) % valid_period == 0:
            print(f'{epoch + 1} training epochs finished\nValidation started: {dt.datetime.now()}')
            with torch.inference_mode():
                wandb_metrics_value = validation(model, valid_loader, metrics, device)
                add_train_metrics(wandb_metrics_value, model, train_loader_metrics, metrics, device)
                wandb_metrics_value.update(criterion.tri_loss.summary())
                wandb.log(wandb_metrics_value)
                
                if wandb_metrics_value['cmc/1'] > best_cmc1:
                    best_cmc1 = wandb_metrics_value['cmc/1']
                    save_model('best.pt', epoch + 1, model, optimizer, scheduler)
                    wandb.save('best.pt')
                    print(f'\nNew best CMC@1 {best_cmc1} at {epoch + 1} epoch\n')
# Out:
# wandb: Currently logged in as: nik-fedorov. Use `wandb login --relogin` to force relogin
# wandb version 0.15.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.0
# Run data is saved locally in <code>/kaggle/working/wandb/run-20230520_093654-et9f8b8s</code>
# Syncing run <strong><a href='https://wandb.ai/nik-fedorov/TP3/runs/et9f8b8s' target="_blank">run</a></strong> to <a href='https://wandb.ai/nik-fedorov/TP3' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nik-fedorov/TP3' target="_blank">https://wandb.ai/nik-fedorov/TP3</a>
#  View run at <a href='https://wandb.ai/nik-fedorov/TP3/runs/et9f8b8s' target="_blank">https://wandb.ai/nik-fedorov/TP3/runs/et9f8b8s</a>
# Evaluating pre-trained model before training
# Inference finished: 2023-05-20 09:38:17.754253
# {'cmc/1': 0.830857515335083, 'map/5': 0.8621483445167542, 'additional/class_sizes/min': tensor(0.4694), 'additional/class_sizes/max': tensor(0.6891), 'additional/class_sizes/mean': tensor(0.5814), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1435), 'additional/inter_class_dist/mean': tensor(0.7877)}
#
# Inference finished: 2023-05-20 09:38:56.015809
# {'cmc/1': 0.844474732875824, 'map/5': 0.8746084570884705, 'additional/class_sizes/min': tensor(0.4522), 'additional/class_sizes/max': tensor(0.6944), 'additional/class_sizes/mean': tensor(0.5822), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1752), 'additional/inter_class_dist/mean': tensor(0.8619)}
#
# 5 training epochs finished
# Validation started: 2023-05-20 09:39:13.663012
# Inference finished: 2023-05-20 09:39:48.167185
# {'cmc/1': 0.8408170342445374, 'map/5': 0.8696579933166504, 'additional/class_sizes/min': tensor(0.4490), 'additional/class_sizes/max': tensor(0.6826), 'additional/class_sizes/mean': tensor(0.5681), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1602), 'additional/inter_class_dist/mean': tensor(0.8090)}
#
# Inference finished: 2023-05-20 09:40:22.986644
# {'cmc/1': 0.8528308272361755, 'map/5': 0.884681761264801, 'additional/class_sizes/min': tensor(0.4455), 'additional/class_sizes/max': tensor(0.6896), 'additional/class_sizes/mean': tensor(0.5704), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1837), 'additional/inter_class_dist/mean': tensor(0.8779)}
#
#
# New best CMC@1 0.8408170342445374 at 5 epoch
#
# 10 training epochs finished
# Validation started: 2023-05-20 09:40:42.608853
# Inference finished: 2023-05-20 09:41:16.941673
# {'cmc/1': 0.8516205549240112, 'map/5': 0.8774743676185608, 'additional/class_sizes/min': tensor(0.4289), 'additional/class_sizes/max': tensor(0.6783), 'additional/class_sizes/mean': tensor(0.5587), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1650), 'additional/inter_class_dist/mean': tensor(0.8168)}
#
# Inference finished: 2023-05-20 09:41:52.290243
# {'cmc/1': 0.8627216815948486, 'map/5': 0.8907017707824707, 'additional/class_sizes/min': tensor(0.4372), 'additional/class_sizes/max': tensor(0.6837), 'additional/class_sizes/mean': tensor(0.5620), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1877), 'additional/inter_class_dist/mean': tensor(0.8824)}
#
#
# New best CMC@1 0.8516205549240112 at 10 epoch
#
# 15 training epochs finished
# Validation started: 2023-05-20 09:42:11.649279
# Inference finished: 2023-05-20 09:42:45.924238
# {'cmc/1': 0.8549966216087341, 'map/5': 0.8803224563598633, 'additional/class_sizes/min': tensor(0.4221), 'additional/class_sizes/max': tensor(0.6733), 'additional/class_sizes/mean': tensor(0.5528), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1659), 'additional/inter_class_dist/mean': tensor(0.8199)}
#
# Inference finished: 2023-05-20 09:43:20.722325
# {'cmc/1': 0.8693724274635315, 'map/5': 0.8942317962646484, 'additional/class_sizes/min': tensor(0.4290), 'additional/class_sizes/max': tensor(0.6768), 'additional/class_sizes/mean': tensor(0.5555), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1922), 'additional/inter_class_dist/mean': tensor(0.8845)}
#
#
# New best CMC@1 0.8549966216087341 at 15 epoch
#
# 20 training epochs finished
# Validation started: 2023-05-20 09:43:39.908377
# Inference finished: 2023-05-20 09:44:15.354836
# {'cmc/1': 0.8578662872314453, 'map/5': 0.8809112310409546, 'additional/class_sizes/min': tensor(0.4185), 'additional/class_sizes/max': tensor(0.6712), 'additional/class_sizes/mean': tensor(0.5470), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1661), 'additional/inter_class_dist/mean': tensor(0.8219)}
#
# Inference finished: 2023-05-20 09:44:50.286829
# {'cmc/1': 0.8738062977790833, 'map/5': 0.8976781964302063, 'additional/class_sizes/min': tensor(0.4241), 'additional/class_sizes/max': tensor(0.6730), 'additional/class_sizes/mean': tensor(0.5504), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1966), 'additional/inter_class_dist/mean': tensor(0.8869)}
#
#
# New best CMC@1 0.8578662872314453 at 20 epoch
#
# 25 training epochs finished
# Validation started: 2023-05-20 09:45:09.613315
# Inference finished: 2023-05-20 09:45:44.272551
# {'cmc/1': 0.8565158843994141, 'map/5': 0.8805713057518005, 'additional/class_sizes/min': tensor(0.4087), 'additional/class_sizes/max': tensor(0.6692), 'additional/class_sizes/mean': tensor(0.5385), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1692), 'additional/inter_class_dist/mean': tensor(0.8276)}
#
# Inference finished: 2023-05-20 09:46:19.408329
# {'cmc/1': 0.8748294711112976, 'map/5': 0.8992544412612915, 'additional/class_sizes/min': tensor(0.4142), 'additional/class_sizes/max': tensor(0.6663), 'additional/class_sizes/mean': tensor(0.5439), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1984), 'additional/inter_class_dist/mean': tensor(0.8927)}
#
# 30 training epochs finished
# Validation started: 2023-05-20 09:46:37.997138
# Inference finished: 2023-05-20 09:47:12.679032
# {'cmc/1': 0.8561782836914062, 'map/5': 0.8811621069908142, 'additional/class_sizes/min': tensor(0.4045), 'additional/class_sizes/max': tensor(0.6611), 'additional/class_sizes/mean': tensor(0.5321), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1665), 'additional/inter_class_dist/mean': tensor(0.8251)}
#
# Inference finished: 2023-05-20 09:47:47.858985
# {'cmc/1': 0.8770464062690735, 'map/5': 0.9009367227554321, 'additional/class_sizes/min': tensor(0.4059), 'additional/class_sizes/max': tensor(0.6577), 'additional/class_sizes/mean': tensor(0.5379), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1963), 'additional/inter_class_dist/mean': tensor(0.8903)}
#
# 35 training epochs finished
# Validation started: 2023-05-20 09:48:06.505039
# Inference finished: 2023-05-20 09:48:41.224897
# {'cmc/1': 0.8563470840454102, 'map/5': 0.8813577890396118, 'additional/class_sizes/min': tensor(0.3993), 'additional/class_sizes/max': tensor(0.6583), 'additional/class_sizes/mean': tensor(0.5281), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1662), 'additional/inter_class_dist/mean': tensor(0.8250)}
#
# Inference finished: 2023-05-20 09:49:16.554205
# {'cmc/1': 0.8775579929351807, 'map/5': 0.9024731516838074, 'additional/class_sizes/min': tensor(0.4049), 'additional/class_sizes/max': tensor(0.6513), 'additional/class_sizes/mean': tensor(0.5336), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1930), 'additional/inter_class_dist/mean': tensor(0.8904)}
#
# 40 training epochs finished
# Validation started: 2023-05-20 09:49:34.953178
# Inference finished: 2023-05-20 09:50:09.497525
# {'cmc/1': 0.8571910858154297, 'map/5': 0.881553053855896, 'additional/class_sizes/min': tensor(0.3983), 'additional/class_sizes/max': tensor(0.6535), 'additional/class_sizes/mean': tensor(0.5254), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1640), 'additional/inter_class_dist/mean': tensor(0.8219)}
#
# Inference finished: 2023-05-20 09:50:44.690768
# {'cmc/1': 0.8780695796012878, 'map/5': 0.9029499292373657, 'additional/class_sizes/min': tensor(0.3995), 'additional/class_sizes/max': tensor(0.6448), 'additional/class_sizes/mean': tensor(0.5294), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1911), 'additional/inter_class_dist/mean': tensor(0.8883)}
#
# 45 training epochs finished
# Validation started: 2023-05-20 09:51:02.424294
# Inference finished: 2023-05-20 09:51:36.835170
# {'cmc/1': 0.8583727478981018, 'map/5': 0.8811684846878052, 'additional/class_sizes/min': tensor(0.4006), 'additional/class_sizes/max': tensor(0.6490), 'additional/class_sizes/mean': tensor(0.5220), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1647), 'additional/inter_class_dist/mean': tensor(0.8197)}
#
# Inference finished: 2023-05-20 09:52:12.177796
# {'cmc/1': 0.8813096880912781, 'map/5': 0.9028865098953247, 'additional/class_sizes/min': tensor(0.3961), 'additional/class_sizes/max': tensor(0.6363), 'additional/class_sizes/mean': tensor(0.5249), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1944), 'additional/inter_class_dist/mean': tensor(0.8887)}
#
#
# New best CMC@1 0.8583727478981018 at 45 epoch
#
# 50 training epochs finished
# Validation started: 2023-05-20 09:52:32.074349
# Inference finished: 2023-05-20 09:53:06.529564
# {'cmc/1': 0.8568534851074219, 'map/5': 0.8817725777626038, 'additional/class_sizes/min': tensor(0.3989), 'additional/class_sizes/max': tensor(0.6410), 'additional/class_sizes/mean': tensor(0.5197), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1619), 'additional/inter_class_dist/mean': tensor(0.8175)}
#
# Inference finished: 2023-05-20 09:53:41.614351
# {'cmc/1': 0.8814802169799805, 'map/5': 0.9031493663787842, 'additional/class_sizes/min': tensor(0.3955), 'additional/class_sizes/max': tensor(0.6308), 'additional/class_sizes/mean': tensor(0.5220), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1931), 'additional/inter_class_dist/mean': tensor(0.8889)}
#
# 55 training epochs finished
# Validation started: 2023-05-20 09:53:59.706009
# Inference finished: 2023-05-20 09:54:34.641744
# {'cmc/1': 0.8568534851074219, 'map/5': 0.8818402886390686, 'additional/class_sizes/min': tensor(0.3959), 'additional/class_sizes/max': tensor(0.6292), 'additional/class_sizes/mean': tensor(0.5164), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1562), 'additional/inter_class_dist/mean': tensor(0.8156)}
#
# Inference finished: 2023-05-20 09:55:09.523442
# {'cmc/1': 0.8789222240447998, 'map/5': 0.9036145806312561, 'additional/class_sizes/min': tensor(0.3934), 'additional/class_sizes/max': tensor(0.6220), 'additional/class_sizes/mean': tensor(0.5185), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1864), 'additional/inter_class_dist/mean': tensor(0.8872)}
#
# 60 training epochs finished
# Validation started: 2023-05-20 09:55:27.944711
# Inference finished: 2023-05-20 09:56:02.779723
# {'cmc/1': 0.8563470840454102, 'map/5': 0.881791353225708, 'additional/class_sizes/min': tensor(0.3939), 'additional/class_sizes/max': tensor(0.6258), 'additional/class_sizes/mean': tensor(0.5147), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1555), 'additional/inter_class_dist/mean': tensor(0.8156)}
#
# Inference finished: 2023-05-20 09:56:37.974220
# {'cmc/1': 0.8804570436477661, 'map/5': 0.9048518538475037, 'additional/class_sizes/min': tensor(0.3874), 'additional/class_sizes/max': tensor(0.6176), 'additional/class_sizes/mean': tensor(0.5159), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1815), 'additional/inter_class_dist/mean': tensor(0.8882)}
#
# 65 training epochs finished
# Validation started: 2023-05-20 09:56:55.801124
# Inference finished: 2023-05-20 09:57:29.788899
# {'cmc/1': 0.8575286865234375, 'map/5': 0.8828182816505432, 'additional/class_sizes/min': tensor(0.3898), 'additional/class_sizes/max': tensor(0.6203), 'additional/class_sizes/mean': tensor(0.5128), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1526), 'additional/inter_class_dist/mean': tensor(0.8143)}
#
# Inference finished: 2023-05-20 09:58:04.670942
# {'cmc/1': 0.8826739192008972, 'map/5': 0.9055730104446411, 'additional/class_sizes/min': tensor(0.3816), 'additional/class_sizes/max': tensor(0.6093), 'additional/class_sizes/mean': tensor(0.5113), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1792), 'additional/inter_class_dist/mean': tensor(0.8886)}
#
# 70 training epochs finished
# Validation started: 2023-05-20 09:58:23.045842
# Inference finished: 2023-05-20 09:58:57.397577
# {'cmc/1': 0.8571910858154297, 'map/5': 0.8829155564308167, 'additional/class_sizes/min': tensor(0.3857), 'additional/class_sizes/max': tensor(0.6165), 'additional/class_sizes/mean': tensor(0.5086), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1522), 'additional/inter_class_dist/mean': tensor(0.8087)}
#
# Inference finished: 2023-05-20 09:59:32.361394
# {'cmc/1': 0.8852319121360779, 'map/5': 0.9066705107688904, 'additional/class_sizes/min': tensor(0.3786), 'additional/class_sizes/max': tensor(0.6086), 'additional/class_sizes/mean': tensor(0.5074), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1739), 'additional/inter_class_dist/mean': tensor(0.8828)}
#
# 75 training epochs finished
# Validation started: 2023-05-20 09:59:50.702717
# Inference finished: 2023-05-20 10:00:25.526172
# {'cmc/1': 0.8563470840454102, 'map/5': 0.8826944828033447, 'additional/class_sizes/min': tensor(0.3862), 'additional/class_sizes/max': tensor(0.6122), 'additional/class_sizes/mean': tensor(0.5044), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1512), 'additional/inter_class_dist/mean': tensor(0.8039)}
#
# Inference finished: 2023-05-20 10:01:00.764818
# {'cmc/1': 0.8852319121360779, 'map/5': 0.9074801206588745, 'additional/class_sizes/min': tensor(0.3798), 'additional/class_sizes/max': tensor(0.6047), 'additional/class_sizes/mean': tensor(0.5030), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1685), 'additional/inter_class_dist/mean': tensor(0.8797)}
#
# 80 training epochs finished
# Validation started: 2023-05-20 10:01:18.827697
# Inference finished: 2023-05-20 10:01:53.296436
# {'cmc/1': 0.8588791489601135, 'map/5': 0.8829042315483093, 'additional/class_sizes/min': tensor(0.3803), 'additional/class_sizes/max': tensor(0.6100), 'additional/class_sizes/mean': tensor(0.5010), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1525), 'additional/inter_class_dist/mean': tensor(0.8065)}
#
# Inference finished: 2023-05-20 10:02:28.528309
# {'cmc/1': 0.8857434988021851, 'map/5': 0.9078247547149658, 'additional/class_sizes/min': tensor(0.3828), 'additional/class_sizes/max': tensor(0.6057), 'additional/class_sizes/mean': tensor(0.5002), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1705), 'additional/inter_class_dist/mean': tensor(0.8834)}
#
#
# New best CMC@1 0.8588791489601135 at 80 epoch
#
# 85 training epochs finished
# Validation started: 2023-05-20 10:02:47.881153
# Inference finished: 2023-05-20 10:03:21.707677
# {'cmc/1': 0.856684684753418, 'map/5': 0.8819440007209778, 'additional/class_sizes/min': tensor(0.3746), 'additional/class_sizes/max': tensor(0.6101), 'additional/class_sizes/mean': tensor(0.4979), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1506), 'additional/inter_class_dist/mean': tensor(0.8035)}
#
# Inference finished: 2023-05-20 10:03:57.058288
# {'cmc/1': 0.8879604339599609, 'map/5': 0.9101455211639404, 'additional/class_sizes/min': tensor(0.3840), 'additional/class_sizes/max': tensor(0.6014), 'additional/class_sizes/mean': tensor(0.4971), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1611), 'additional/inter_class_dist/mean': tensor(0.8813)}
#
# 90 training epochs finished
# Validation started: 2023-05-20 10:04:15.542105
# Inference finished: 2023-05-20 10:04:50.650944
# {'cmc/1': 0.8568534851074219, 'map/5': 0.8819343447685242, 'additional/class_sizes/min': tensor(0.3707), 'additional/class_sizes/max': tensor(0.6162), 'additional/class_sizes/mean': tensor(0.4974), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1545), 'additional/inter_class_dist/mean': tensor(0.8067)}
#
# Inference finished: 2023-05-20 10:05:25.832511
# {'cmc/1': 0.890688955783844, 'map/5': 0.9117595553398132, 'additional/class_sizes/min': tensor(0.3726), 'additional/class_sizes/max': tensor(0.5941), 'additional/class_sizes/mean': tensor(0.4954), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1588), 'additional/inter_class_dist/mean': tensor(0.8867)}
#
# 95 training epochs finished
# Validation started: 2023-05-20 10:05:44.293146
# Inference finished: 2023-05-20 10:06:18.892507
# {'cmc/1': 0.8549966216087341, 'map/5': 0.8822062611579895, 'additional/class_sizes/min': tensor(0.3738), 'additional/class_sizes/max': tensor(0.6168), 'additional/class_sizes/mean': tensor(0.4978), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1530), 'additional/inter_class_dist/mean': tensor(0.8084)}
#
# Inference finished: 2023-05-20 10:06:54.161948
# {'cmc/1': 0.8901773691177368, 'map/5': 0.9118105173110962, 'additional/class_sizes/min': tensor(0.3674), 'additional/class_sizes/max': tensor(0.5920), 'additional/class_sizes/mean': tensor(0.4946), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1645), 'additional/inter_class_dist/mean': tensor(0.8920)}
#
# 100 training epochs finished
# Validation started: 2023-05-20 10:07:12.567633
# Inference finished: 2023-05-20 10:07:46.378767
# {'cmc/1': 0.8543214201927185, 'map/5': 0.8820691704750061, 'additional/class_sizes/min': tensor(0.3696), 'additional/class_sizes/max': tensor(0.6150), 'additional/class_sizes/mean': tensor(0.4965), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1521), 'additional/inter_class_dist/mean': tensor(0.8068)}
#
# Inference finished: 2023-05-20 10:08:21.504538
# {'cmc/1': 0.8917121291160583, 'map/5': 0.9133238196372986, 'additional/class_sizes/min': tensor(0.3673), 'additional/class_sizes/max': tensor(0.5898), 'additional/class_sizes/mean': tensor(0.4934), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1635), 'additional/inter_class_dist/mean': tensor(0.8915)}
#
# 105 training epochs finished
# Validation started: 2023-05-20 10:08:39.383137
# Inference finished: 2023-05-20 10:09:14.009536
# {'cmc/1': 0.8538150191307068, 'map/5': 0.881680965423584, 'additional/class_sizes/min': tensor(0.3690), 'additional/class_sizes/max': tensor(0.6161), 'additional/class_sizes/mean': tensor(0.4948), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1478), 'additional/inter_class_dist/mean': tensor(0.8034)}
#
# Inference finished: 2023-05-20 10:09:49.112846
# {'cmc/1': 0.893417477607727, 'map/5': 0.9143409729003906, 'additional/class_sizes/min': tensor(0.3652), 'additional/class_sizes/max': tensor(0.5899), 'additional/class_sizes/mean': tensor(0.4929), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1603), 'additional/inter_class_dist/mean': tensor(0.8881)}
#
# 110 training epochs finished
# Validation started: 2023-05-20 10:10:07.544392
# Inference finished: 2023-05-20 10:10:42.319596
# {'cmc/1': 0.8516205549240112, 'map/5': 0.8812882304191589, 'additional/class_sizes/min': tensor(0.3703), 'additional/class_sizes/max': tensor(0.6156), 'additional/class_sizes/mean': tensor(0.4946), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1455), 'additional/inter_class_dist/mean': tensor(0.8061)}
#
# Inference finished: 2023-05-20 10:11:17.258139
# {'cmc/1': 0.8937585353851318, 'map/5': 0.9151449203491211, 'additional/class_sizes/min': tensor(0.3577), 'additional/class_sizes/max': tensor(0.5827), 'additional/class_sizes/mean': tensor(0.4907), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1623), 'additional/inter_class_dist/mean': tensor(0.8931)}
#
# 115 training epochs finished
# Validation started: 2023-05-20 10:11:35.622099
# Inference finished: 2023-05-20 10:12:10.385044
# {'cmc/1': 0.8553342223167419, 'map/5': 0.8818626403808594, 'additional/class_sizes/min': tensor(0.3740), 'additional/class_sizes/max': tensor(0.6188), 'additional/class_sizes/mean': tensor(0.4940), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1479), 'additional/inter_class_dist/mean': tensor(0.8070)}
#
# Inference finished: 2023-05-20 10:12:45.323447
# {'cmc/1': 0.8961459994316101, 'map/5': 0.915091872215271, 'additional/class_sizes/min': tensor(0.3600), 'additional/class_sizes/max': tensor(0.5797), 'additional/class_sizes/mean': tensor(0.4892), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1621), 'additional/inter_class_dist/mean': tensor(0.8950)}
#
# 120 training epochs finished
# Validation started: 2023-05-20 10:13:03.025242
# Inference finished: 2023-05-20 10:13:36.780362
# {'cmc/1': 0.8543214201927185, 'map/5': 0.8823305368423462, 'additional/class_sizes/min': tensor(0.3768), 'additional/class_sizes/max': tensor(0.6164), 'additional/class_sizes/mean': tensor(0.4924), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1509), 'additional/inter_class_dist/mean': tensor(0.8051)}
#
# Inference finished: 2023-05-20 10:14:13.251016
# {'cmc/1': 0.8973397016525269, 'map/5': 0.9156808853149414, 'additional/class_sizes/min': tensor(0.3588), 'additional/class_sizes/max': tensor(0.5777), 'additional/class_sizes/mean': tensor(0.4853), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1631), 'additional/inter_class_dist/mean': tensor(0.8960)}
#
# 125 training epochs finished
# Validation started: 2023-05-20 10:14:31.436017
# Inference finished: 2023-05-20 10:15:06.310987
# {'cmc/1': 0.8533085584640503, 'map/5': 0.8808073401451111, 'additional/class_sizes/min': tensor(0.3748), 'additional/class_sizes/max': tensor(0.6143), 'additional/class_sizes/mean': tensor(0.4903), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1493), 'additional/inter_class_dist/mean': tensor(0.8040)}
#
# Inference finished: 2023-05-20 10:15:41.079067
# {'cmc/1': 0.8961459994316101, 'map/5': 0.9159525036811829, 'additional/class_sizes/min': tensor(0.3572), 'additional/class_sizes/max': tensor(0.5760), 'additional/class_sizes/mean': tensor(0.4819), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1644), 'additional/inter_class_dist/mean': tensor(0.8948)}
#
# 130 training epochs finished
# Validation started: 2023-05-20 10:15:59.570294
# Inference finished: 2023-05-20 10:16:34.467998
# {'cmc/1': 0.8522957563400269, 'map/5': 0.880505383014679, 'additional/class_sizes/min': tensor(0.3697), 'additional/class_sizes/max': tensor(0.6111), 'additional/class_sizes/mean': tensor(0.4864), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1460), 'additional/inter_class_dist/mean': tensor(0.8028)}
#
# Inference finished: 2023-05-20 10:17:09.567364
# {'cmc/1': 0.8975102305412292, 'map/5': 0.9167050123214722, 'additional/class_sizes/min': tensor(0.3585), 'additional/class_sizes/max': tensor(0.5742), 'additional/class_sizes/mean': tensor(0.4795), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1636), 'additional/inter_class_dist/mean': tensor(0.8922)}
#
# 135 training epochs finished
# Validation started: 2023-05-20 10:17:27.925046
# Inference finished: 2023-05-20 10:18:02.132167
# {'cmc/1': 0.8511140942573547, 'map/5': 0.8798556923866272, 'additional/class_sizes/min': tensor(0.3689), 'additional/class_sizes/max': tensor(0.6068), 'additional/class_sizes/mean': tensor(0.4861), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1456), 'additional/inter_class_dist/mean': tensor(0.8013)}
#
# Inference finished: 2023-05-20 10:18:37.522648
# {'cmc/1': 0.9007503390312195, 'map/5': 0.9189077019691467, 'additional/class_sizes/min': tensor(0.3586), 'additional/class_sizes/max': tensor(0.5721), 'additional/class_sizes/mean': tensor(0.4795), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1631), 'additional/inter_class_dist/mean': tensor(0.8915)}
#
# 140 training epochs finished
# Validation started: 2023-05-20 10:18:55.670955
# Inference finished: 2023-05-20 10:19:30.501849
# {'cmc/1': 0.8507764935493469, 'map/5': 0.8800563812255859, 'additional/class_sizes/min': tensor(0.3716), 'additional/class_sizes/max': tensor(0.6014), 'additional/class_sizes/mean': tensor(0.4856), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1394), 'additional/inter_class_dist/mean': tensor(0.7919)}
#
# Inference finished: 2023-05-20 10:20:05.527318
# {'cmc/1': 0.9004092812538147, 'map/5': 0.9187974333763123, 'additional/class_sizes/min': tensor(0.3629), 'additional/class_sizes/max': tensor(0.5681), 'additional/class_sizes/mean': tensor(0.4786), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1573), 'additional/inter_class_dist/mean': tensor(0.8847)}
#
# 145 training epochs finished
# Validation started: 2023-05-20 10:20:23.290158
# Inference finished: 2023-05-20 10:20:58.000079
# {'cmc/1': 0.8511140942573547, 'map/5': 0.8808118104934692, 'additional/class_sizes/min': tensor(0.3754), 'additional/class_sizes/max': tensor(0.5977), 'additional/class_sizes/mean': tensor(0.4827), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1343), 'additional/inter_class_dist/mean': tensor(0.7867)}
#
# Inference finished: 2023-05-20 10:21:33.165522
# {'cmc/1': 0.8995566368103027, 'map/5': 0.9186661243438721, 'additional/class_sizes/min': tensor(0.3590), 'additional/class_sizes/max': tensor(0.5628), 'additional/class_sizes/mean': tensor(0.4761), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1550), 'additional/inter_class_dist/mean': tensor(0.8819)}
#
# 150 training epochs finished
# Validation started: 2023-05-20 10:21:51.684826
# Inference finished: 2023-05-20 10:22:25.936557
# {'cmc/1': 0.8512828946113586, 'map/5': 0.880499005317688, 'additional/class_sizes/min': tensor(0.3798), 'additional/class_sizes/max': tensor(0.5910), 'additional/class_sizes/mean': tensor(0.4805), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1360), 'additional/inter_class_dist/mean': tensor(0.7846)}
#
# Inference finished: 2023-05-20 10:23:01.006313
# {'cmc/1': 0.9004092812538147, 'map/5': 0.918952226638794, 'additional/class_sizes/min': tensor(0.3563), 'additional/class_sizes/max': tensor(0.5591), 'additional/class_sizes/mean': tensor(0.4733), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1504), 'additional/inter_class_dist/mean': tensor(0.8823)}
#
# 155 training epochs finished
# Validation started: 2023-05-20 10:23:19.477747
# Inference finished: 2023-05-20 10:23:53.694858
# {'cmc/1': 0.8531397581100464, 'map/5': 0.8805321455001831, 'additional/class_sizes/min': tensor(0.3776), 'additional/class_sizes/max': tensor(0.5979), 'additional/class_sizes/mean': tensor(0.4784), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1383), 'additional/inter_class_dist/mean': tensor(0.7832)}
#
# Inference finished: 2023-05-20 10:24:28.485391
# {'cmc/1': 0.9017735123634338, 'map/5': 0.9199879765510559, 'additional/class_sizes/min': tensor(0.3590), 'additional/class_sizes/max': tensor(0.5599), 'additional/class_sizes/mean': tensor(0.4719), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1480), 'additional/inter_class_dist/mean': tensor(0.8813)}
#
# 160 training epochs finished
# Validation started: 2023-05-20 10:24:46.465083
# Inference finished: 2023-05-20 10:25:21.811778
# {'cmc/1': 0.8539838194847107, 'map/5': 0.8804331421852112, 'additional/class_sizes/min': tensor(0.3764), 'additional/class_sizes/max': tensor(0.5991), 'additional/class_sizes/mean': tensor(0.4791), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1403), 'additional/inter_class_dist/mean': tensor(0.7841)}
#
# Inference finished: 2023-05-20 10:25:56.960746
# {'cmc/1': 0.9022851586341858, 'map/5': 0.9203300476074219, 'additional/class_sizes/min': tensor(0.3573), 'additional/class_sizes/max': tensor(0.5610), 'additional/class_sizes/mean': tensor(0.4717), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1472), 'additional/inter_class_dist/mean': tensor(0.8826)}
#
# 165 training epochs finished
# Validation started: 2023-05-20 10:26:14.810374
# Inference finished: 2023-05-20 10:26:49.621146
# {'cmc/1': 0.850607693195343, 'map/5': 0.8795157074928284, 'additional/class_sizes/min': tensor(0.3774), 'additional/class_sizes/max': tensor(0.5968), 'additional/class_sizes/mean': tensor(0.4795), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1403), 'additional/inter_class_dist/mean': tensor(0.7837)}
#
# Inference finished: 2023-05-20 10:27:23.876517
# {'cmc/1': 0.9026262164115906, 'map/5': 0.920707106590271, 'additional/class_sizes/min': tensor(0.3588), 'additional/class_sizes/max': tensor(0.5601), 'additional/class_sizes/mean': tensor(0.4706), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1470), 'additional/inter_class_dist/mean': tensor(0.8844)}
#
# 170 training epochs finished
# Validation started: 2023-05-20 10:27:41.936390
# Inference finished: 2023-05-20 10:28:16.783810
# {'cmc/1': 0.8517893552780151, 'map/5': 0.8803011775016785, 'additional/class_sizes/min': tensor(0.3798), 'additional/class_sizes/max': tensor(0.5937), 'additional/class_sizes/mean': tensor(0.4805), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1332), 'additional/inter_class_dist/mean': tensor(0.7803)}
#
# Inference finished: 2023-05-20 10:28:51.910035
# {'cmc/1': 0.9029672741889954, 'map/5': 0.9211305975914001, 'additional/class_sizes/min': tensor(0.3590), 'additional/class_sizes/max': tensor(0.5581), 'additional/class_sizes/mean': tensor(0.4707), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1469), 'additional/inter_class_dist/mean': tensor(0.8827)}
#
# 175 training epochs finished
# Validation started: 2023-05-20 10:29:10.438739
# Inference finished: 2023-05-20 10:29:44.306350
# {'cmc/1': 0.852126955986023, 'map/5': 0.8805984258651733, 'additional/class_sizes/min': tensor(0.3728), 'additional/class_sizes/max': tensor(0.5918), 'additional/class_sizes/mean': tensor(0.4782), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1350), 'additional/inter_class_dist/mean': tensor(0.7793)}
#
# Inference finished: 2023-05-20 10:30:18.887320
# {'cmc/1': 0.9038199186325073, 'map/5': 0.9215614199638367, 'additional/class_sizes/min': tensor(0.3493), 'additional/class_sizes/max': tensor(0.5548), 'additional/class_sizes/mean': tensor(0.4681), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1478), 'additional/inter_class_dist/mean': tensor(0.8822)}
#
# 180 training epochs finished
# Validation started: 2023-05-20 10:30:36.395911
# Inference finished: 2023-05-20 10:31:11.379672
# {'cmc/1': 0.8517893552780151, 'map/5': 0.8804401755332947, 'additional/class_sizes/min': tensor(0.3717), 'additional/class_sizes/max': tensor(0.5898), 'additional/class_sizes/mean': tensor(0.4772), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1337), 'additional/inter_class_dist/mean': tensor(0.7825)}
#
# Inference finished: 2023-05-20 10:31:46.595833
# {'cmc/1': 0.9036493897438049, 'map/5': 0.922554075717926, 'additional/class_sizes/min': tensor(0.3488), 'additional/class_sizes/max': tensor(0.5551), 'additional/class_sizes/mean': tensor(0.4661), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1530), 'additional/inter_class_dist/mean': tensor(0.8894)}
#
# 185 training epochs finished
# Validation started: 2023-05-20 10:32:04.310821
# Inference finished: 2023-05-20 10:32:39.314808
# {'cmc/1': 0.8543214201927185, 'map/5': 0.8813287615776062, 'additional/class_sizes/min': tensor(0.3723), 'additional/class_sizes/max': tensor(0.5923), 'additional/class_sizes/mean': tensor(0.4786), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1348), 'additional/inter_class_dist/mean': tensor(0.7845)}
#
# Inference finished: 2023-05-20 10:33:14.545120
# {'cmc/1': 0.9045020341873169, 'map/5': 0.9230749011039734, 'additional/class_sizes/min': tensor(0.3519), 'additional/class_sizes/max': tensor(0.5565), 'additional/class_sizes/mean': tensor(0.4653), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1554), 'additional/inter_class_dist/mean': tensor(0.8937)}
#
# 190 training epochs finished
# Validation started: 2023-05-20 10:33:32.846522
# Inference finished: 2023-05-20 10:34:07.170680
# {'cmc/1': 0.8522957563400269, 'map/5': 0.8805993795394897, 'additional/class_sizes/min': tensor(0.3699), 'additional/class_sizes/max': tensor(0.5914), 'additional/class_sizes/mean': tensor(0.4774), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1360), 'additional/inter_class_dist/mean': tensor(0.7846)}
#
# Inference finished: 2023-05-20 10:34:42.363669
# {'cmc/1': 0.9043315052986145, 'map/5': 0.9233450889587402, 'additional/class_sizes/min': tensor(0.3476), 'additional/class_sizes/max': tensor(0.5524), 'additional/class_sizes/mean': tensor(0.4628), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1524), 'additional/inter_class_dist/mean': tensor(0.8948)}
#
# 195 training epochs finished
# Validation started: 2023-05-20 10:35:00.365437
# Inference finished: 2023-05-20 10:35:34.002837
# {'cmc/1': 0.850607693195343, 'map/5': 0.8798766136169434, 'additional/class_sizes/min': tensor(0.3676), 'additional/class_sizes/max': tensor(0.5885), 'additional/class_sizes/mean': tensor(0.4738), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1336), 'additional/inter_class_dist/mean': tensor(0.7812)}
#
# Inference finished: 2023-05-20 10:36:09.109857
# {'cmc/1': 0.9068894982337952, 'map/5': 0.9244564771652222, 'additional/class_sizes/min': tensor(0.3441), 'additional/class_sizes/max': tensor(0.5476), 'additional/class_sizes/mean': tensor(0.4591), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1432), 'additional/inter_class_dist/mean': tensor(0.8922)}
#
# 200 training epochs finished
# Validation started: 2023-05-20 10:36:26.827959
# Inference finished: 2023-05-20 10:37:01.687011
# {'cmc/1': 0.8511140942573547, 'map/5': 0.8797532320022583, 'additional/class_sizes/min': tensor(0.3617), 'additional/class_sizes/max': tensor(0.5873), 'additional/class_sizes/mean': tensor(0.4743), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1323), 'additional/inter_class_dist/mean': tensor(0.7831)}
#
# Inference finished: 2023-05-20 10:37:36.992959
# {'cmc/1': 0.9067189693450928, 'map/5': 0.9246622323989868, 'additional/class_sizes/min': tensor(0.3428), 'additional/class_sizes/max': tensor(0.5480), 'additional/class_sizes/mean': tensor(0.4588), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1486), 'additional/inter_class_dist/mean': tensor(0.8950)}
#
# 205 training epochs finished
# Validation started: 2023-05-20 10:37:54.761400
# Inference finished: 2023-05-20 10:38:28.761395
# {'cmc/1': 0.8511140942573547, 'map/5': 0.8795781135559082, 'additional/class_sizes/min': tensor(0.3597), 'additional/class_sizes/max': tensor(0.5891), 'additional/class_sizes/mean': tensor(0.4741), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1304), 'additional/inter_class_dist/mean': tensor(0.7815)}
#
# Inference finished: 2023-05-20 10:39:04.044443
# {'cmc/1': 0.9072305560112, 'map/5': 0.9256579279899597, 'additional/class_sizes/min': tensor(0.3469), 'additional/class_sizes/max': tensor(0.5479), 'additional/class_sizes/mean': tensor(0.4591), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1497), 'additional/inter_class_dist/mean': tensor(0.8958)}
#
# 210 training epochs finished
# Validation started: 2023-05-20 10:39:22.337331
# Inference finished: 2023-05-20 10:39:56.269998
# {'cmc/1': 0.8501012921333313, 'map/5': 0.8790054321289062, 'additional/class_sizes/min': tensor(0.3585), 'additional/class_sizes/max': tensor(0.5910), 'additional/class_sizes/mean': tensor(0.4750), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1296), 'additional/inter_class_dist/mean': tensor(0.7816)}
#
# Inference finished: 2023-05-20 10:40:31.367685
# {'cmc/1': 0.9084242582321167, 'map/5': 0.9257665872573853, 'additional/class_sizes/min': tensor(0.3429), 'additional/class_sizes/max': tensor(0.5472), 'additional/class_sizes/mean': tensor(0.4584), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1477), 'additional/inter_class_dist/mean': tensor(0.8995)}
#
# 215 training epochs finished
# Validation started: 2023-05-20 10:40:49.258639
# Inference finished: 2023-05-20 10:41:23.879935
# {'cmc/1': 0.8538150191307068, 'map/5': 0.8806249499320984, 'additional/class_sizes/min': tensor(0.3534), 'additional/class_sizes/max': tensor(0.5919), 'additional/class_sizes/mean': tensor(0.4760), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1333), 'additional/inter_class_dist/mean': tensor(0.7848)}
#
# Inference finished: 2023-05-20 10:41:59.148702
# {'cmc/1': 0.9087653756141663, 'map/5': 0.926604688167572, 'additional/class_sizes/min': tensor(0.3441), 'additional/class_sizes/max': tensor(0.5496), 'additional/class_sizes/mean': tensor(0.4595), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1480), 'additional/inter_class_dist/mean': tensor(0.9014)}
#
# 220 training epochs finished
# Validation started: 2023-05-20 10:42:16.672073
# Inference finished: 2023-05-20 10:42:51.422716
# {'cmc/1': 0.850607693195343, 'map/5': 0.8792526721954346, 'additional/class_sizes/min': tensor(0.3479), 'additional/class_sizes/max': tensor(0.5947), 'additional/class_sizes/mean': tensor(0.4749), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1388), 'additional/inter_class_dist/mean': tensor(0.7896)}
#
# Inference finished: 2023-05-20 10:43:26.530823
# {'cmc/1': 0.9103001356124878, 'map/5': 0.9275625348091125, 'additional/class_sizes/min': tensor(0.3481), 'additional/class_sizes/max': tensor(0.5482), 'additional/class_sizes/mean': tensor(0.4600), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1501), 'additional/inter_class_dist/mean': tensor(0.9051)}
#
# 225 training epochs finished
# Validation started: 2023-05-20 10:43:44.888754
# Inference finished: 2023-05-20 10:44:19.487080
# {'cmc/1': 0.8516205549240112, 'map/5': 0.8795771598815918, 'additional/class_sizes/min': tensor(0.3475), 'additional/class_sizes/max': tensor(0.5900), 'additional/class_sizes/mean': tensor(0.4734), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1401), 'additional/inter_class_dist/mean': tensor(0.7916)}
#
# Inference finished: 2023-05-20 10:44:54.376029
# {'cmc/1': 0.9103001356124878, 'map/5': 0.9280903339385986, 'additional/class_sizes/min': tensor(0.3448), 'additional/class_sizes/max': tensor(0.5437), 'additional/class_sizes/mean': tensor(0.4571), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1523), 'additional/inter_class_dist/mean': tensor(0.9078)}
#
# 230 training epochs finished
# Validation started: 2023-05-20 10:45:12.423952
# Inference finished: 2023-05-20 10:45:46.130249
# {'cmc/1': 0.8497636914253235, 'map/5': 0.8795321583747864, 'additional/class_sizes/min': tensor(0.3471), 'additional/class_sizes/max': tensor(0.5875), 'additional/class_sizes/mean': tensor(0.4718), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1327), 'additional/inter_class_dist/mean': tensor(0.7869)}
#
# Inference finished: 2023-05-20 10:46:21.007421
# {'cmc/1': 0.909106433391571, 'map/5': 0.9285769462585449, 'additional/class_sizes/min': tensor(0.3368), 'additional/class_sizes/max': tensor(0.5383), 'additional/class_sizes/mean': tensor(0.4542), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1470), 'additional/inter_class_dist/mean': tensor(0.9025)}
#
# 235 training epochs finished
# Validation started: 2023-05-20 10:46:38.983794
# Inference finished: 2023-05-20 10:47:14.226485
# {'cmc/1': 0.847400426864624, 'map/5': 0.8781744837760925, 'additional/class_sizes/min': tensor(0.3456), 'additional/class_sizes/max': tensor(0.5877), 'additional/class_sizes/mean': tensor(0.4699), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1329), 'additional/inter_class_dist/mean': tensor(0.7872)}
#
# Inference finished: 2023-05-20 10:47:49.304492
# {'cmc/1': 0.9097885489463806, 'map/5': 0.9277503490447998, 'additional/class_sizes/min': tensor(0.3329), 'additional/class_sizes/max': tensor(0.5388), 'additional/class_sizes/mean': tensor(0.4515), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1426), 'additional/inter_class_dist/mean': tensor(0.9033)}
#
# 240 training epochs finished
# Validation started: 2023-05-20 10:48:07.104411
# Inference finished: 2023-05-20 10:48:41.678209
# {'cmc/1': 0.8468939661979675, 'map/5': 0.8770642876625061, 'additional/class_sizes/min': tensor(0.3478), 'additional/class_sizes/max': tensor(0.5890), 'additional/class_sizes/mean': tensor(0.4697), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1334), 'additional/inter_class_dist/mean': tensor(0.7853)}
#
# Inference finished: 2023-05-20 10:49:16.687070
# {'cmc/1': 0.9125170707702637, 'map/5': 0.9283291697502136, 'additional/class_sizes/min': tensor(0.3336), 'additional/class_sizes/max': tensor(0.5375), 'additional/class_sizes/mean': tensor(0.4513), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1423), 'additional/inter_class_dist/mean': tensor(0.9047)}
#
# 245 training epochs finished
# Validation started: 2023-05-20 10:49:35.270117
# Inference finished: 2023-05-20 10:50:09.811551
# {'cmc/1': 0.8484132289886475, 'map/5': 0.8769435882568359, 'additional/class_sizes/min': tensor(0.3465), 'additional/class_sizes/max': tensor(0.5917), 'additional/class_sizes/mean': tensor(0.4661), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1333), 'additional/inter_class_dist/mean': tensor(0.7822)}
#
# Inference finished: 2023-05-20 10:50:44.657752
# {'cmc/1': 0.9118348956108093, 'map/5': 0.9285106062889099, 'additional/class_sizes/min': tensor(0.3366), 'additional/class_sizes/max': tensor(0.5333), 'additional/class_sizes/mean': tensor(0.4489), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1379), 'additional/inter_class_dist/mean': tensor(0.9031)}
#
# 250 training epochs finished
# Validation started: 2023-05-20 10:51:03.024124
# Inference finished: 2023-05-20 10:51:37.217435
# {'cmc/1': 0.8479068279266357, 'map/5': 0.87779301404953, 'additional/class_sizes/min': tensor(0.3468), 'additional/class_sizes/max': tensor(0.5932), 'additional/class_sizes/mean': tensor(0.4690), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1306), 'additional/inter_class_dist/mean': tensor(0.7827)}
#
# Inference finished: 2023-05-20 10:52:12.118156
# {'cmc/1': 0.9123465418815613, 'map/5': 0.928715169429779, 'additional/class_sizes/min': tensor(0.3378), 'additional/class_sizes/max': tensor(0.5324), 'additional/class_sizes/mean': tensor(0.4497), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1337), 'additional/inter_class_dist/mean': tensor(0.9055)}
#
# 255 training epochs finished
# Validation started: 2023-05-20 10:52:29.932347
# Inference finished: 2023-05-20 10:53:04.556651
# {'cmc/1': 0.8504388928413391, 'map/5': 0.8783587217330933, 'additional/class_sizes/min': tensor(0.3445), 'additional/class_sizes/max': tensor(0.5921), 'additional/class_sizes/mean': tensor(0.4684), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1291), 'additional/inter_class_dist/mean': tensor(0.7815)}
#
# Inference finished: 2023-05-20 10:53:38.458282
# {'cmc/1': 0.913540244102478, 'map/5': 0.9302158951759338, 'additional/class_sizes/min': tensor(0.3405), 'additional/class_sizes/max': tensor(0.5361), 'additional/class_sizes/mean': tensor(0.4504), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1311), 'additional/inter_class_dist/mean': tensor(0.9045)}
#
# 260 training epochs finished
# Validation started: 2023-05-20 10:53:56.327526
# Inference finished: 2023-05-20 10:54:30.848411
# {'cmc/1': 0.8512828946113586, 'map/5': 0.8794683814048767, 'additional/class_sizes/min': tensor(0.3476), 'additional/class_sizes/max': tensor(0.5917), 'additional/class_sizes/mean': tensor(0.4683), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1261), 'additional/inter_class_dist/mean': tensor(0.7796)}
#
# Inference finished: 2023-05-20 10:55:05.599537
# {'cmc/1': 0.9123465418815613, 'map/5': 0.9303314685821533, 'additional/class_sizes/min': tensor(0.3386), 'additional/class_sizes/max': tensor(0.5388), 'additional/class_sizes/mean': tensor(0.4506), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1295), 'additional/inter_class_dist/mean': tensor(0.9021)}
#
# 265 training epochs finished
# Validation started: 2023-05-20 10:55:24.026616
# Inference finished: 2023-05-20 10:55:58.778450
# {'cmc/1': 0.8507764935493469, 'map/5': 0.8786652684211731, 'additional/class_sizes/min': tensor(0.3472), 'additional/class_sizes/max': tensor(0.5989), 'additional/class_sizes/mean': tensor(0.4712), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1286), 'additional/inter_class_dist/mean': tensor(0.7832)}
#
# Inference finished: 2023-05-20 10:56:33.825855
# ...
#
# 660 training epochs finished
# Validation started: 2023-05-20 12:51:29.287059
# Inference finished: 2023-05-20 12:52:05.067462
# {'cmc/1': 0.8317015767097473, 'map/5': 0.862585186958313, 'additional/class_sizes/min': tensor(0.3476), 'additional/class_sizes/max': tensor(0.6244), 'additional/class_sizes/mean': tensor(0.4862), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1210), 'additional/inter_class_dist/mean': tensor(0.7989)}
#
# Inference finished: 2023-05-20 12:52:41.286578
# {'cmc/1': 0.9512278437614441, 'map/5': 0.9612141251564026, 'additional/class_sizes/min': tensor(0.3355), 'additional/class_sizes/max': tensor(0.5225), 'additional/class_sizes/mean': tensor(0.4377), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.2020), 'additional/inter_class_dist/mean': tensor(0.9856)}
#
# 665 training epochs finished
# Validation started: 2023-05-20 12:53:00.286673
# Inference finished: 2023-05-20 12:53:36.210520
# {'cmc/1': 0.8317015767097473, 'map/5': 0.8627804517745972, 'additional/class_sizes/min': tensor(0.3547), 'additional/class_sizes/max': tensor(0.6200), 'additional/class_sizes/mean': tensor(0.4884), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1135), 'additional/inter_class_dist/mean': tensor(0.7955)}
#
# Inference finished: 2023-05-20 12:54:12.046998
# {'cmc/1': 0.9517394304275513, 'map/5': 0.9618756771087646, 'additional/class_sizes/min': tensor(0.3385), 'additional/class_sizes/max': tensor(0.5225), 'additional/class_sizes/mean': tensor(0.4389), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1984), 'additional/inter_class_dist/mean': tensor(0.9836)}
#
# 670 training epochs finished
# Validation started: 2023-05-20 12:54:31.033219
# Inference finished: 2023-05-20 12:55:07.122951
# {'cmc/1': 0.8305199146270752, 'map/5': 0.860949695110321, 'additional/class_sizes/min': tensor(0.3643), 'additional/class_sizes/max': tensor(0.6276), 'additional/class_sizes/mean': tensor(0.4937), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1084), 'additional/inter_class_dist/mean': tensor(0.7957)}
#
# Inference finished: 2023-05-20 12:55:43.119846
# {'cmc/1': 0.9515689015388489, 'map/5': 0.9622787833213806, 'additional/class_sizes/min': tensor(0.3334), 'additional/class_sizes/max': tensor(0.5299), 'additional/class_sizes/mean': tensor(0.4406), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.2016), 'additional/inter_class_dist/mean': tensor(0.9864)}
#
# 675 training epochs finished
# Validation started: 2023-05-20 12:56:02.008569
# Inference finished: 2023-05-20 12:56:37.793362
# {'cmc/1': 0.8298447132110596, 'map/5': 0.8615918755531311, 'additional/class_sizes/min': tensor(0.3602), 'additional/class_sizes/max': tensor(0.6321), 'additional/class_sizes/mean': tensor(0.4898), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1136), 'additional/inter_class_dist/mean': tensor(0.7963)}
#
# Inference finished: 2023-05-20 12:57:13.982118
# {'cmc/1': 0.952933132648468, 'map/5': 0.9625204205513, 'additional/class_sizes/min': tensor(0.3341), 'additional/class_sizes/max': tensor(0.5222), 'additional/class_sizes/mean': tensor(0.4391), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1991), 'additional/inter_class_dist/mean': tensor(0.9866)}
#
# 680 training epochs finished
# Validation started: 2023-05-20 12:57:32.172426
# Inference finished: 2023-05-20 12:58:07.523352
# {'cmc/1': 0.8296759128570557, 'map/5': 0.8620695471763611, 'additional/class_sizes/min': tensor(0.3608), 'additional/class_sizes/max': tensor(0.6359), 'additional/class_sizes/mean': tensor(0.4934), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1131), 'additional/inter_class_dist/mean': tensor(0.7982)}
#
# Inference finished: 2023-05-20 12:58:43.476216
# {'cmc/1': 0.9546384811401367, 'map/5': 0.9632337093353271, 'additional/class_sizes/min': tensor(0.3363), 'additional/class_sizes/max': tensor(0.5202), 'additional/class_sizes/mean': tensor(0.4400), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1984), 'additional/inter_class_dist/mean': tensor(0.9897)}
#
# 685 training epochs finished
# Validation started: 2023-05-20 12:59:01.943089
# Inference finished: 2023-05-20 12:59:37.968194
# {'cmc/1': 0.8327143788337708, 'map/5': 0.8635929822921753, 'additional/class_sizes/min': tensor(0.3544), 'additional/class_sizes/max': tensor(0.6366), 'additional/class_sizes/mean': tensor(0.4919), 'additional/inter_class_dist/min': tensor(0.0002), 'additional/inter_class_dist/max': tensor(1.1136), 'additional/inter_class_dist/mean': tensor(0.8002)}
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>additional/class_sizes/max</td><td>█▇▆▄▃▃▃▃▂▂▁▁▁▁▁▁▂▂▂▂▂▂▂▂▁▂▂▃▃▃▃▄▄▄▄▄▄▄▄▄</td></tr><tr><td>additional/class_sizes/mean</td><td>█▇▅▄▄▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃</td></tr><tr><td>additional/class_sizes/min</td><td>█▆▅▅▄▃▃▃▃▃▃▃▂▁▁▁▂▁▁▂▂▂▂▂▁▂▂▂▂▂▂▂▂▂▂▃▃▂▂▂</td></tr><tr><td>additional/inter_class_dist/max</td><td>▇██▇▆▆▆▆▅▄▄▄▃▅▄▃▅▃▂▂▁▁▁▂▁▂▂▂▃▃▃▂▃▂▂▄▄▂▂▁</td></tr><tr><td>additional/inter_class_dist/mean</td><td>▆▇█▇▇▅▅▅▅▃▂▃▂▄▃▂▃▃▃▂▁▂▁▃▃▂▃▃▄▄▄▅▅▆▅▆▅▄▅▄</td></tr><tr><td>additional/inter_class_dist/min</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>cmc/1</td><td>▄▇████▇▇▆▇▇▇▆▇▆▆▆▆▅▅▅▄▅▅▄▅▄▃▃▃▄▃▂▂▂▂▁▂▁▁</td></tr><tr><td>d(a,n)-d(a,p)/max</td><td>▃▅▆▂▄▂▂▆▁▄▁▄▄▃▄▄▄▆▂▃▄▃▃▆▄▃▄▆▅▅▅▇▅▆▄▆▄██▆</td></tr><tr><td>d(a,n)-d(a,p)/mean</td><td>▁▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇█▇███</td></tr><tr><td>d(a,n)-d(a,p)/min</td><td>▂▃▅▆▅▄▂▆▂▅▃▄▆▄▅▄▃▆▅▇▆▄▄▇▄▆▁▅▅▆▇▇▄█▆▅▃▆▁▃</td></tr><tr><td>d(a,n)-d(a,p)/std</td><td>▄▇█▄▅▃▄▃▂▁▂▃▂▄▃▂▃▃▃▄▃▃▁▂▂▂▃▂▄▄▂▃▄▅▂▃▅▄▃▅</td></tr><tr><td>d(a,n)/max</td><td>▅▄▆▄▃▆▅▄▂▃▂▂█▂▂▂▃▂▃▄▁▃▁▃▂▄▂▃▅▅▃▄▄▃▆▄▄▄▃▆</td></tr><tr><td>d(a,n)/mean</td><td>██▆▅▅▄▄▃▃▃▂▂▂▁▂▂▂▃▃▂▁▂▂▃▃▃▄▄▄▅▅▅▆▆▆▆▆▇▇▆</td></tr><tr><td>d(a,n)/min</td><td>█▆▆▇▇▆▅▇█▆▆▇▄▃▅▇▅█▇▇▇█▄▇▇▇▁▆▆▆██▇█▇▇▇▇▅▂</td></tr><tr><td>d(a,n)/std</td><td>█▇▇▅▅▄▄▆▃▁▂▆▆▇▅▄▅▄▃▄▄▆▄▂▃▄▅▄▅▄▅▅▄▅▃▃▃▂▂▆</td></tr><tr><td>d(a,p)/max</td><td>▇▅▆▄▃▅▅▄▃▂▂▃█▁▃▄▂▁▃▂▁▂▁▅▂▄▁▅▄▃▂▄▄▃▆▅▄▄▃▅</td></tr><tr><td>d(a,p)/mean</td><td>█▇▆▅▅▄▄▃▃▃▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▂▁▁▁▁▁▁</td></tr><tr><td>d(a,p)/min</td><td>▇█▅▅▆▄▅▃▄▅▃▄▃▄▃▄▁▃▄▃▃▄▃▃▃▃▃▃▂▃▄▂▃▄▃▃▃▁▁▃</td></tr><tr><td>d(a,p)/std</td><td>▆▆█▅▅▃▅▃▄▂▃▂▂▃▂▂▃▂▂▄▁▂▁▃▃▂▁▂▃▃▃▃▄▄▄▃▆▅▄▅</td></tr><tr><td>d(p,n)/max</td><td>██▅▄▅▄▄▃▄▁▁▁▂▁▁▁▃▁▄▃▂▅▂▇▁▃▂▄▄▇▃▅▆▆▅▆▆▅▄▃</td></tr><tr><td>d(p,n)/mean</td><td>██▆▅▄▄▄▃▃▃▂▂▁▁▂▂▂▂▂▂▁▂▂▃▂▃▃▃▄▄▄▅▅▅▅▆▅▆▅▅</td></tr><tr><td>d(p,n)/min</td><td>█▄▅▅▅▄▅▆▆▄▅▅▃▂▅▅▄▆▅▅▅▆▄▅▆▆▁▅▅▅▆▇▅▆▅▅▇▅▃▂</td></tr><tr><td>d(p,n)/std</td><td>█▇▆▆▅▅▄▅▂▁▂▆▆▇▆▄▅▄▃▅▃▆▅▃▃▂▅▄▆▅▆▅▅▅▄▄▄▃▂▆</td></tr><tr><td>map/5</td><td>▄▇█████▇▇▇▇█▇▇▆▇▆▆▆▆▅▅▅▅▄▅▅▃▂▃▃▂▂▂▂▂▂▂▁▁</td></tr><tr><td>train/additional/class_sizes/max</td><td>█▇▆▅▅▄▄▃▃▃▂▂▂▂▁▂▂▂▂▁▁▁▁▁▁▁▁▁▂▁▁▂▂▂▂▂▂▂▁▁</td></tr><tr><td>train/additional/class_sizes/mean</td><td>█▇▆▅▅▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁</td></tr><tr><td>train/additional/class_sizes/min</td><td>█▇▆▅▄▄▃▃▃▃▂▃▂▂▂▂▁▂▁▁▂▂▁▂▁▂▁▂▂▂▂▂▂▂▂▁▁▂▁▁</td></tr><tr><td>train/additional/inter_class_dist/max</td><td>▆▆▆▆▅▄▄▄▄▂▂▃▃▃▂▁▂▃▃▃▂▂▂▃▃▃▄▅▆▆▇▆▇▇▆█▇▆▇▇</td></tr><tr><td>train/additional/inter_class_dist/mean</td><td>▁▁▂▂▂▁▂▂▂▁▁▂▂▃▃▃▄▄▄▃▃▄▄▅▅▅▅▆▆▆▆▇▇█▇██▇██</td></tr><tr><td>train/additional/inter_class_dist/min</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/cmc/1</td><td>▁▂▃▃▃▃▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇█▇███</td></tr><tr><td>train/map/5</td><td>▁▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>additional/class_sizes/max</td><td>0.63589</td></tr><tr><td>additional/class_sizes/mean</td><td>0.49344</td></tr><tr><td>additional/class_sizes/min</td><td>0.36078</td></tr><tr><td>additional/inter_class_dist/max</td><td>1.11313</td></tr><tr><td>additional/inter_class_dist/mean</td><td>0.7982</td></tr><tr><td>additional/inter_class_dist/min</td><td>0.00024</td></tr><tr><td>cmc/1</td><td>0.82968</td></tr><tr><td>d(a,n)-d(a,p)/max</td><td>0.69835</td></tr><tr><td>d(a,n)-d(a,p)/mean</td><td>0.26022</td></tr><tr><td>d(a,n)-d(a,p)/min</td><td>-0.39955</td></tr><tr><td>d(a,n)-d(a,p)/std</td><td>0.17232</td></tr><tr><td>d(a,n)/max</td><td>1.29558</td></tr><tr><td>d(a,n)/mean</td><td>0.92764</td></tr><tr><td>d(a,n)/min</td><td>0.39786</td></tr><tr><td>d(a,n)/std</td><td>0.11011</td></tr><tr><td>d(a,p)/max</td><td>1.31451</td></tr><tr><td>d(a,p)/mean</td><td>0.66741</td></tr><tr><td>d(a,p)/min</td><td>0.35931</td></tr><tr><td>d(a,p)/std</td><td>0.12686</td></tr><tr><td>d(p,n)/max</td><td>1.2284</td></tr><tr><td>d(p,n)/mean</td><td>0.96232</td></tr><tr>< ...
#  View run <strong style="color:#cdcd00">run</strong> at: <a href='https://wandb.ai/nik-fedorov/TP3/runs/et9f8b8s' target="_blank">https://wandb.ai/nik-fedorov/TP3/runs/et9f8b8s</a><br/>Synced 6 W&B file(s), 0 media file(s), 2 artifact file(s) and 2 other file(s)
# Find logs at: <code>./wandb/run-20230520_093654-et9f8b8s/logs</code>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 57
#      55 with torch.inference_mode():
#      56     wandb_metrics_value = validation(model, valid_loader, metrics, device)
# ---> 57     add_train_metrics(wandb_metrics_value, model, train_loader_metrics, metrics, device)
#      58     wandb_metrics_value.update(criterion.tri_loss.summary())
#      59     wandb.log(wandb_metrics_value)
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[3], line 103, in add_train_metrics(wandb_metrics_value, model, train_loader, metrics, device)
#     101 @torch.no_grad()
#     102 def add_train_metrics(wandb_metrics_value, model, train_loader, metrics, device):
# --> 103     train_metrics_value = validation(model, train_loader, metrics, device)
#     104     for metric, value in train_metrics_value.items():
#     105         wandb_metrics_value['train/' + metric] = value
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[3], line 88, in validation(model, valid_loader, metrics, device)
#      85 @torch.no_grad()
#      86 def validation(model, valid_loader, metrics, device):
#      87     model.eval()
# ---> 88     embeds, labels = inference(model, valid_loader, device)
#      89     print(f'Inference finished: {dt.datetime.now()}')
#      91     dist_mat = torch.cdist(embeds, embeds, p=2)
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# Cell In[3], line 48, in inference(model, valid_loader, device)
#      45 @torch.no_grad()
#      46 def inference(model, valid_loader, device):
#      47     embeds, labels = [], []
# ---> 48     for batch in valid_loader:
#      49         # embeds += [F.normalize(model.body(batch['input_tensors'].to(device)), p=2, dim=1)]
#      50         embeds += [model(batch['input_tensors'].to(device))]
#      51         labels += [batch['labels']]
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:628, in _BaseDataLoaderIter.__next__(self)
#     625 if self._sampler_iter is None:
#     626     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     627     self._reset()  # type: ignore[call-arg]
# --> 628 data = self._next_data()
#     629 self._num_yielded += 1
#     630 if self._dataset_kind == _DatasetKind.Iterable and \
#     631         self._IterableDataset_len_called is not None and \
#     632         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1316, in _MultiProcessingDataLoaderIter._next_data(self)
#    1313     return self._process_data(data)
#    1315 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1316 idx, data = self._get_data()
#    1317 self._tasks_outstanding -= 1
#    1318 if self._dataset_kind == _DatasetKind.Iterable:
#    1319     # Check for _IterableDatasetStopIteration
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1282, in _MultiProcessingDataLoaderIter._get_data(self)
#    1278     # In this case, `self._data_queue` is a `queue.Queue`,. But we don't
#    1279     # need to call `.task_done()` because we don't use `.join()`.
#    1280 else:
#    1281     while True:
# -> 1282         success, data = self._try_get_data()
#    1283         if success:
#    1284             return data
#
# File /opt/conda/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1120, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1107 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1108     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1109     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1117     # Returns a 2-tuple:
#    1118     #   (bool: whether successfully get data, any: data if successful else None)
#    1119     try:
# -> 1120         data = self._data_queue.get(timeout=timeout)
#    1121         return (True, data)
#    1122     except Exception as e:
#    1123         # At timeout and error, we manually check whether any worker has
#    1124         # failed. Note that this is the only mechanism for Windows to detect
#    1125         # worker failures.
#
# File /opt/conda/lib/python3.10/multiprocessing/queues.py:113, in Queue.get(self, block, timeout)
#     111 if block:
#     112     timeout = deadline - time.monotonic()
# --> 113     if not self._poll(timeout):
#     114         raise Empty
#     115 elif not self._poll():
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:257, in _ConnectionBase.poll(self, timeout)
#     255 self._check_closed()
#     256 self._check_readable()
# --> 257 return self._poll(timeout)
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:424, in Connection._poll(self, timeout)
#     423 def _poll(self, timeout):
# --> 424     r = wait([self], timeout)
#     425     return bool(r)
#
# File /opt/conda/lib/python3.10/multiprocessing/connection.py:931, in wait(object_list, timeout)
#     928     deadline = time.monotonic() + timeout
#     930 while True:
# --> 931     ready = selector.select(timeout)
#     932     if ready:
#     933         return [key.fileobj for (key, events) in ready]
#
# File /opt/conda/lib/python3.10/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:

# %% [markdown]
# # Loading model from wandb and resume training

# %%
import wandb
best_model = wandb.restore('best.pt', run_path="nik-fedorov/TP3/f0ian1ey")

# model = ViTExtractor('vits16_dino', arch='vits16', normalise_features=False).to(device)
# model = timm.create_model('vit_small_patch16_224', pretrained=True).to(device)
load_model(best_model.name, device, model, optimizer)

# %%
torch.manual_seed(42)

n_epochs = 10000
valid_period = 10

metrics = {
    'cmc_top_k': [1],  # to calculate cmc@1
    'map_top_k': [5],  # to calculate map@5
    'precision_top_k': [],
    'fmr_vals': []
}

wandb_init_data = {
    'project': 'TP3',
    'name': 'run',
    'save_code': True,
    'config': {
        'model': 'ViT',
        'optimizer': optimizer,
        'scheduler': scheduler,
        'sampler': {
            'name': 'balanced',
            'n_labels': n_labels,
            'n_instances': n_instances
        },
        
        'valid_period': valid_period,

        'dataset': 'CUB_200_2011',
        'num_epochs': n_epochs,
        'dataloader_num_workers': num_workers,
        'script': _ih[-1]
    }
}

with wandb.init(**wandb_init_data) as run:
    print('Evaluating pre-trained model before training')
    wandb_metrics_value = validation(model, valid_loader, metrics, device)
    wandb.log(wandb_metrics_value)
    best_cmc1 = wandb_metrics_value['cmc/1']
    
    for epoch in range(n_epochs):
        model.train()
        for batch in train_loader:
            optimizer.zero_grad()
            embeddings = model(batch['input_tensors'].to(device))
            loss = criterion(embeddings, batch['labels'].to(device))
            loss.backward()
            optimizer.step()

        if (epoch + 1) % valid_period == 0:
            print(f'{epoch + 1} training epochs finished\nValidation started: {dt.datetime.now()}')
            with torch.inference_mode():
                wandb_metrics_value = validation(model, valid_loader, metrics, device)
                wandb.log(wandb_metrics_value)
                
                if wandb_metrics_value['cmc/1'] > best_cmc1:
                    best_cmc1 = wandb_metrics_value['cmc/1']
                    save_model('best.pt', epoch + 1, model, optimizer, scheduler)
                    wandb.save('best.pt')
                    print(f'\nNew best CMC@1 {best_cmc1} at {epoch + 1} epoch\n')
